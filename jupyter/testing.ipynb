# %%
import pandas as pd
import json, os

import sys
sys.path.append('..')
from scripts import models

# %%
archivos = os.listdir('../datasets/results')
dfs = [pd.read_csv(f'../datasets/results/{a}') for a in archivos]

df = pd.concat(dfs)
df.sample(5)
# Out:
#                        model  \
# 4257    KNeighborsClassifier
# 7199    KNeighborsClassifier
# 1626    KNeighborsClassifier
# 166     KNeighborsClassifier
# 2199  RandomForestClassifier
#
#                                         hyperparameters      time  accuracy
# 4257  {'n_neighbors': 5, 'weights': 'distance', 'alg...  0.068804  0.666667
# 7199  {'n_neighbors': 11, 'weights': 'uniform', 'alg...  0.168017  0.693548
# 1626  {'n_neighbors': 11, 'weights': 'distance', 'al...  0.239506  0.688172
# 166   {'n_neighbors': 11, 'weights': 'distance', 'al...  0.127173  0.693548
# 2199  {'n_estimators': 60, 'criterion': 'gini', 'max...  1.095425  0.833333

# %%
df.groupby('model').count()
# Out:
#                         hyperparameters   time  accuracy
# model
# DecisionTreeClassifier              177    177       177
# KNeighborsClassifier              11400  11400     11400
# LogisticRegression                  245    245       196
# RandomForestClassifier             3132   3132      3132

# %%
# Elimino los valores nulos
df = df.dropna().reset_index(drop = True)
df.sample(5)
# Out:
#                         model  \
# 1461     KNeighborsClassifier
# 510      KNeighborsClassifier
# 13038  RandomForestClassifier
# 2086     KNeighborsClassifier
# 3415     KNeighborsClassifier
#
#                                          hyperparameters      time  accuracy
# 1461   {'n_neighbors': 9, 'weights': 'uniform', 'algo...  0.137362  0.666667
# 510    {'n_neighbors': 19, 'weights': 'distance', 'al...  0.253474  0.720430
# 13038  {'n_estimators': 240, 'criterion': 'entropy', ...  3.003200  0.865591
# 2086   {'n_neighbors': 13, 'weights': 'distance', 'al...  0.198232  0.693548
# 3415   {'n_neighbors': 8, 'weights': 'distance', 'alg...  0.222603  0.698925

# %%
# df.to_csv('../datasets/results/all-models-results.csv', index = False)

# %%
df.sort_values('accuracy', ascending=False)
# Out:
#                         model  \
# 14514  RandomForestClassifier
# 13793  RandomForestClassifier
# 13799  RandomForestClassifier
# 13815  RandomForestClassifier
# 12099  RandomForestClassifier
# ...                       ...
# 10055    KNeighborsClassifier
# 4785     KNeighborsClassifier
# 6050     KNeighborsClassifier
# 10147    KNeighborsClassifier
# 10125    KNeighborsClassifier
#
#                                          hyperparameters      time  accuracy
# 14514  {'n_estimators': 200, 'criterion': 'gini', 'ma...  2.947827  0.881720
# 13793  {'n_estimators': 220, 'criterion': 'entropy', ...  2.697781  0.881720
# 13799  {'n_estimators': 140, 'criterion': 'entropy', ...  1.824711  0.881720
# 13815  {'n_estimators': 40, 'criterion': 'entropy', '...  0.942399  0.881720
# 12099  {'n_estimators': 60, 'criterion': 'entropy', '...  0.833916  0.881720
# ...                                                  ...       ...       ...
# 10055  {'n_neighbors': 3, 'weights': 'distance', 'alg...  0.136731  0.639785
# 4785   {'n_neighbors': 3, 'weights': 'distance', 'alg...  0.133117  0.639785
# 6050   {'n_neighbors': 3, 'weights': 'distance', 'alg...  0.100938  0.639785
# 10147  {'n_neighbors': 3, 'weights': 'distance', 'alg...  0.248328  0.639785
# 10125  {'n_neighbors': 3, 'weights': 'distance', 'alg...  0.239405  0.639785
#
# [14905 rows x 4 columns]

# %% [markdown]
# #### KNeighborsClassifier

# %%
df.loc[df.model == 'KNeighborsClassifier'].sort_values('accuracy', ascending=False)[:5]
# Out:
#                       model  \
# 10578  KNeighborsClassifier
# 10588  KNeighborsClassifier
# 1063   KNeighborsClassifier
# 11571  KNeighborsClassifier
# 6277   KNeighborsClassifier
#
#                                          hyperparameters      time  accuracy
# 10578  {'n_neighbors': 18, 'weights': 'distance', 'al...  0.182928  0.741935
# 10588  {'n_neighbors': 18, 'weights': 'distance', 'al...  0.213513  0.741935
# 1063   {'n_neighbors': 18, 'weights': 'distance', 'al...  0.129921  0.741935
# 11571  {'n_neighbors': 18, 'weights': 'distance', 'al...  0.141084  0.741935
# 6277   {'n_neighbors': 18, 'weights': 'distance', 'al...  0.211244  0.741935

# %% [markdown]
# #### RandomForestClassifier

# %%
df.loc[df.model == 'RandomForestClassifier'].sort_values('accuracy', ascending=False)[:5]a
# Out:
#                         model  \
# 14865  RandomForestClassifier
# 13908  RandomForestClassifier
# 12099  RandomForestClassifier
# 12089  RandomForestClassifier
# 13799  RandomForestClassifier
#
#                                          hyperparameters      time  accuracy
# 14865  {'n_estimators': 50, 'criterion': 'entropy', '...  0.543346   0.88172
# 13908  {'n_estimators': 40, 'criterion': 'gini', 'max...  0.635044   0.88172
# 12099  {'n_estimators': 60, 'criterion': 'entropy', '...  0.833916   0.88172
# 12089  {'n_estimators': 100, 'criterion': 'gini', 'ma...  1.582156   0.88172
# 13799  {'n_estimators': 140, 'criterion': 'entropy', ...  1.824711   0.88172

# %% [markdown]
# #### DecisionTreeClassifier

# %%
df.loc[df.model == 'DecisionTreeClassifier'].sort_values('accuracy', ascending=False)[:5]
# Out:
#                       model  \
# 134  DecisionTreeClassifier
# 138  DecisionTreeClassifier
# 92   DecisionTreeClassifier
# 122  DecisionTreeClassifier
# 164  DecisionTreeClassifier
#
#                                        hyperparameters      time  accuracy
# 134  {'criterion': 'log_loss', 'max_depth': 5, 'acc...  0.023000  0.849462
# 138  {'criterion': 'entropy', 'max_depth': 5, 'accu...  0.028993  0.849462
# 92   {'criterion': 'log_loss', 'max_depth': 3, 'acc...  0.040845  0.844086
# 122  {'criterion': 'gini', 'max_depth': 5, 'accurac...  0.109241  0.844086
# 164  {'criterion': 'gini', 'max_depth': 6, 'accurac...  0.082212  0.844086

# %% [markdown]
# #### LogisticRegression

# %%
df.loc[df.model == 'LogisticRegression'].sort_values('accuracy', ascending=False)[:5]
# Out:
#                     model                                    hyperparameters  \
# 11606  LogisticRegression  {'penalty': 'l2', 'C': 0.5, 'max_iter': 100, '...
# 11641  LogisticRegression  {'penalty': 'l2', 'C': 0.5, 'max_iter': 250, '...
# 11583  LogisticRegression  {'penalty': 'l2', 'C': 0.5, 'max_iter': 350, '...
# 11663  LogisticRegression  {'penalty': 'l2', 'C': 0.5, 'max_iter': 200, '...
# 11709  LogisticRegression  {'penalty': 'l2', 'C': 0.5, 'max_iter': 150, '...
#
#            time  accuracy
# 11606  0.045005  0.849462
# 11641  0.018304  0.849462
# 11583  0.008001  0.849462
# 11663  0.042458  0.849462
# 11709  0.012001  0.849462

# %% [markdown]
# #### Selección de los mejores hiperparametros para **RandomForestClassifier**

# %%
rf_parameters = df.loc[df.model == 'RandomForestClassifier'].sort_values('accuracy', ascending=False)
best_parameters = rf_parameters.loc[rf_parameters.accuracy > 0.87]
best_parameters
# Out:
#                         model  \
# 14865  RandomForestClassifier
# 13908  RandomForestClassifier
# 12099  RandomForestClassifier
# 12089  RandomForestClassifier
# 13799  RandomForestClassifier
# ...                       ...
# 14326  RandomForestClassifier
# 13608  RandomForestClassifier
# 13439  RandomForestClassifier
# 13421  RandomForestClassifier
# 14802  RandomForestClassifier
#
#                                          hyperparameters      time  accuracy
# 14865  {'n_estimators': 50, 'criterion': 'entropy', '...  0.543346  0.881720
# 13908  {'n_estimators': 40, 'criterion': 'gini', 'max...  0.635044  0.881720
# 12099  {'n_estimators': 60, 'criterion': 'entropy', '...  0.833916  0.881720
# 12089  {'n_estimators': 100, 'criterion': 'gini', 'ma...  1.582156  0.881720
# 13799  {'n_estimators': 140, 'criterion': 'entropy', ...  1.824711  0.881720
# ...                                                  ...       ...       ...
# 14326  {'n_estimators': 260, 'criterion': 'entropy', ...  3.201598  0.870968
# 13608  {'n_estimators': 50, 'criterion': 'gini', 'max...  1.021842  0.870968
# 13439  {'n_estimators': 240, 'criterion': 'entropy', ...  3.118380  0.870968
# 13421  {'n_estimators': 160, 'criterion': 'gini', 'ma...  2.296792  0.870968
# 14802  {'n_estimators': 50, 'criterion': 'gini', 'max...  0.763004  0.870968
#
# [271 rows x 4 columns]

# %%
best_parameters = pd.json_normalize(best_parameters.hyperparameters.apply(eval))
best_parameters.head()
# Out:
#    n_estimators criterion  max_depth  min_samples_split  min_samples_leaf  \
# 0            50   entropy         17                  2                 2
# 1            40      gini         17                  2                 2
# 2            60   entropy         10                  2                 2
# 3           100      gini          9                  2                 2
# 4           140   entropy          7                  3                 2
#
#    accuracy
# 0   0.88172
# 1   0.88172
# 2   0.88172
# 3   0.88172
# 4   0.88172

# %%
best_parameters.sort_values(
    by = ['accuracy', 'n_estimators','max_depth', 'min_samples_split'],
    ascending = [False, True, True, True]).head()
# Out:
#    n_estimators criterion  max_depth  min_samples_split  min_samples_leaf  \
# 7            40   entropy         12                  4                 2
# 1            40      gini         17                  2                 2
# 0            50   entropy         17                  2                 2
# 2            60   entropy         10                  2                 2
# 6            60      gini         16                  4                 2
#
#    accuracy
# 7   0.88172
# 1   0.88172
# 0   0.88172
# 2   0.88172
# 6   0.88172

# %% [markdown]
# <mark>Acá puedo notar que los mejores hiperparametros para el random forest son los siguientes:
#
# - **n_estimators: 40**
# - **criterion: gini**
# - **max_depth: 17**
# - **min_samples_split: 2**
# - **min_samples_leaf: 2**

# %%
best_parameters.iloc[1].to_json()
# Out:
# '{"n_estimators":40,"criterion":"gini","max_depth":17,"min_samples_split":2,"min_samples_leaf":2,"accuracy":0.8817204301}'
